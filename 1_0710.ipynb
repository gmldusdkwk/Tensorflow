# %%
import tensorflow as tf

# %%
hello = tf.constant("Hello, TensorFlow!")
sess = tf.Session()
print(sess.run(hello))
# b = Bytes string
# Out:
# b'Hello, TensorFlow!'

# %% [markdown]
# ### graph build

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)
node3 = tf.add(node1, node2)

print("node1: ",node1,"node2: ",node2)
print("node3: ",node3)
# Out:
# node1:  Tensor("Const_3:0", shape=(), dtype=float32) node2:  Tensor("Const_4:0", shape=(), dtype=float32)
# node3:  Tensor("Add:0", shape=(), dtype=float32)

# %% [markdown]
# ### session(op)

# %%
sess = tf.Session() #op
print("sess.run(node1, node2): ", sess.run([node1, node2]))
print("sess.run(node3): ",sess.run(node3))
# Out:
# sess.run(node1, node2):  [3.0, 4.0]
# sess.run(node3):  7.0

# %% [markdown]
# ### Placeholder
# - graph build 할 때 이용할 수 있다.
# - 내가 값을 필요할 때 마다 던져준다.
# - 값을 직접 주지 않아도 된다.

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b

print(sess.run(adder_node, feed_dict = {a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict = {a:[ 1, 3], b: [2, 4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# ### Tensor
# - Rank: 몇 차원
# - Shape: 몇 차원 - 각 차원의 원소의 개수

# %% [markdown]
# # Linear Regression
# - H(x) = W * x + b
# - cost(x) = 최소분산법

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = x_train*W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train) #train node 를 실행시킨다는 의미 모든 node가 연결되어있으므로 모든 과정 실행 의미 
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 21.283382 [-0.6454599] [-1.1225094]
# 20 0.2073624 [0.96936333] [-0.39340973]
# 40 0.014951111 [1.1172022] [-0.3105197]
# 60 0.012006867 [1.1256342] [-0.28979415]
# 80 0.010890588 [1.1210572] [-0.27559108]
# 100 0.009890889 [1.1154944] [-0.2625838]
# 120 0.008983065 [1.1100785] [-0.25023803]
# 140 0.008158547 [1.1049064] [-0.23847723]
# 160 0.007409729 [1.0999763] [-0.22726977]
# 180 0.006729635 [1.0952778] [-0.2165889]
# 200 0.006111969 [1.0908002] [-0.20641005]
# 220 0.0055509903 [1.0865328] [-0.1967095]
# 240 0.0050415 [1.0824662] [-0.1874649]
# 260 0.0045787687 [1.0785905] [-0.1786548]
# 280 0.004158509 [1.074897] [-0.17025869]
# 300 0.0037768304 [1.0713773] [-0.16225718]
# 320 0.0034301777 [1.0680227] [-0.15463169]
# 340 0.0031153348 [1.0648259] [-0.14736457]
# 360 0.0028294015 [1.0617794] [-0.14043902]
# 380 0.002569706 [1.0588759] [-0.13383889]
# 400 0.002333855 [1.0561091] [-0.12754895]
# 420 0.0021196406 [1.053472] [-0.12155458]
# 440 0.0019250879 [1.050959] [-0.11584194]
# 460 0.0017483962 [1.0485641] [-0.11039774]
# 480 0.0015879208 [1.0462818] [-0.1052094]
# 500 0.0014421736 [1.0441067] [-0.10026499]
# 520 0.0013098073 [1.0420339] [-0.09555294]
# 540 0.0011895887 [1.0400583] [-0.09106228]
# 560 0.0010804032 [1.0381757] [-0.08678257]
# 580 0.0009812359 [1.0363817] [-0.08270405]
# 600 0.00089117215 [1.0346718] [-0.07881729]
# 620 0.0008093777 [1.0330423] [-0.07511315]
# 640 0.0007350925 [1.0314895] [-0.07158311]
# 660 0.0006676205 [1.0300096] [-0.06821901]
# 680 0.0006063474 [1.0285994] [-0.06501298]
# 1860 2.070072e-06 [1.0016712] [-0.00379873]
# 1880 1.8803056e-06 [1.0015926] [-0.00362026]
# 1900 1.7076572e-06 [1.0015178] [-0.00345018]
# 1920 1.5509835e-06 [1.0014466] [-0.00328808]
# 1940 1.4087618e-06 [1.0013787] [-0.00313367]
# 1960 1.279504e-06 [1.0013137] [-0.00298646]
# 1980 1.1621207e-06 [1.0012522] [-0.00284618]
# 2000 1.0554741e-06 [1.0011934] [-0.00271251]

# %% [markdown]
# ### Placeholders

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

for step in range(2001):
    cost_val, W_val, b_val, _ = \
    sess.run([cost, W, b, train], feed_dict = {X:[1, 2, 3],Y:[1, 2, 3]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.0554741e-06 [1.0011905] [-0.00270599]
# 20 9.587606e-07 [1.0011346] [-0.0025789]
# 40 8.708003e-07 [1.0010813] [-0.00245779]
# 60 7.909778e-07 [1.0010306] [-0.00234237]
# 80 7.1829555e-07 [1.0009822] [-0.00223236]
# 100 6.525279e-07 [1.0009362] [-0.00212754]
# 120 5.9269905e-07 [1.0008923] [-0.00202768]
# 140 5.3836635e-07 [1.0008503] [-0.0019325]
# 160 4.889666e-07 [1.0008103] [-0.00184177]
# 180 4.442173e-07 [1.0007721] [-0.00175535]
# 200 4.034573e-07 [1.0007361] [-0.00167296]
# 220 3.6652605e-07 [1.0007017] [-0.0015944]
# 240 3.3284255e-07 [1.0006684] [-0.00151961]
# 260 3.0239485e-07 [1.0006374] [-0.00144837]
# 280 2.7468178e-07 [1.0006075] [-0.00138038]
# 300 2.495398e-07 [1.0005789] [-0.00131573]
# 320 2.2675009e-07 [1.0005519] [-0.00125397]
# 340 2.0596421e-07 [1.0005257] [-0.00119522]
# 360 1.8709498e-07 [1.0005014] [-0.00113913]
# 380 1.699302e-07 [1.0004776] [-0.00108575]
# 400 1.5434534e-07 [1.0004555] [-0.00103477]
# 420 1.4025692e-07 [1.000434] [-0.00098638]
# 440 1.273903e-07 [1.0004137] [-0.00094004]
# 460 1.1576168e-07 [1.0003946] [-0.00089612]
# 480 1.05129345e-07 [1.0003756] [-0.00085412]
# 500 9.553778e-08 [1.0003583] [-0.00081406]
# 520 8.684723e-08 [1.0003417] [-0.00077605]
# 540 7.880162e-08 [1.0003253] [-0.0007396]
# 560 7.163815e-08 [1.0003104] [-0.00070492]
# 580 6.512848e-08 [1.000296] [-0.00067206]
# 600 5.9187304e-08 [1.0002817] [-0.00064061]
# 620 5.3689863e-08 [1.0002687] [-0.00061045]
# 640 4.881036e-08 [1.0002563] [-0.00058193]
# 660 4.4375053e-08 [1.0002444] [-0.00055486]
# 680 4.0280614e-08 [1.0002325] [-0.00052886]
# 700 3.659721e-08 [1.0002217] [-0.00050391]
# 720 3.3271235e-08 [1.0002116] [-0.00048034]
# 740 3.0255624e-08 [1.000202] [-0.00045805]
# 760 2.7504607e-08 [1.0001924] [-0.00043682]
# 780 2.4978073e-08 [1.0001829] [-0.00041631]
# 800 2.2662471e-08 [1.0001745] [-0.00039664]
# 820 2.0619789e-08 [1.0001664] [-0.00037805]
# 840 1.873219e-08 [1.0001589] [-0.00036047]
# 860 1.7057086e-08 [1.0001518] [-0.00034387]
# 880 1.5526222e-08 [1.0001446] [-0.00032804]
# 900 1.40903955e-08 [1.0001374] [-0.00031271]
# 920 1.278627e-08 [1.0001309] [-0.00029786]
